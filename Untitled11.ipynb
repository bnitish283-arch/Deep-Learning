# %% [markdown]
# <a href="https://colab.research.google.com/github/bnitish283-arch/Deep-Learning/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
# Load Fshion-MNIST dataset

(X_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalize

X_train = X_train / 255.0
x_test = x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
plt.figure(figsize=(6,6))
for i in range(9):
  plt.subplot(3,3,i+1)
  plt.imshow(X_train[i], cmap='gray')
  plt.title(f'Label: {y_train[i]}')
  plt.axis('off')
plt.suptitle("Sample clothing Images")
plt.show()

# %%
unique, counts = np.unique(y_train, return_counts=True)
plt.figure()
plt.bar(unique, counts)
plt.title("Class distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
model = keras.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10,activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from logging import logProcesses
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train , y_train,
    epochs=15,
    validation_data=(x_test, y_test)
)
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8243 - loss: 0.5016 - val_accuracy: 0.8500 - val_loss: 0.4128
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8625 - loss: 0.3814 - val_accuracy: 0.8437 - val_loss: 0.4332
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8757 - loss: 0.3407 - val_accuracy: 0.8696 - val_loss: 0.3591
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8841 - loss: 0.3158 - val_accuracy: 0.8660 - val_loss: 0.3700
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8894 - loss: 0.2976 - val_accuracy: 0.8737 - val_loss: 0.3488
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8961 - loss: 0.2825 - val_accuracy: 0.8717 - val_loss: 0.3470
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8985 - loss: 0.2701 - val_accuracy: 0.8769 - val_loss: 0.3501
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9036 - loss: 0.2586 - val_accuracy: 0.8806 - val_loss: 0.3334
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9068 - loss: 0.2494 - val_accuracy: 0.8735 - val_loss: 0.3512
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9091 - loss: 0.2415 - val_accuracy: 0.8845 - val_loss: 0.3347
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9130 - loss: 0.2322 - val_accuracy: 0.8852 - val_loss: 0.3345
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9150 - loss: 0.2262 - val_accuracy: 0.8788 - val_loss: 0.3394
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9183 - loss: 0.2180 - val_accuracy: 0.8850 - val_loss: 0.3355
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9201 - loss: 0.2110 - val_accuracy: 0.8718 - val_loss: 0.3798
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9223 - loss: 0.2060 - val_accuracy: 0.8844 - val_loss: 0.3481

# %%
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title("loss curve (optimization + generalization)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:",test_acc * 100)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8844 - loss: 0.3481
# Test Accuracy: 88.44000101089478

# %%
preds = model.predict(x_test[:9])

plt.figure(figsize=(6,6))
for i in range(9):
  plt.subplot(3,3,i+1)
  plt.imshow(x_test[i], cmap='gray')
  plt.title(f"P:{np.argmax(preds[i])} A:{y_test[i]}")
  plt.axis('off')
plt.suptitle("Predicions vs Actual")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = np.argmax(model.predict(x_test), axis=1)
cm = confusion_matrix(y_test, y_test)

plt.figure()
sns.heatmap(cm)
plt.title("Confusion Matrix")
plt.show()
#
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
